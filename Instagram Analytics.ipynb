es (68.5%19980288/28781056 bytes (69.4%20242432/28781056 bytes (70.3%20480000/28781056 bytes (71.2%20545536/28781056 bytes (71.4%20676608/28781056 bytes (71.8%20709376/28781056 bytes (72.0%21078016/28781056 bytes (73.2%21168128/28781056 bytes (73.5%21315584/28781056 bytes (74.1%21446656/28781056 bytes (74.5%21594112/28781056 bytes (75.0%21757952/28781056 bytes (75.6%21889024/28781056 bytes (76.1%22069248/28781056 bytes (76.7%22216704/28781056 bytes (77.2%22364160/28781056 bytes (77.7%22495232/28781056 bytes (78.2%22642688/28781056 bytes (78.7%22806528/28781056 bytes (79.2%22953984/28781056 bytes (79.8%23093248/28781056 bytes (80.2%23265280/28781056 bytes (80.8%23412736/28781056 bytes (81.3%23576576/28781056 bytes (81.9%23756800/28781056 bytes (82.5%23920640/28781056 bytes (83.1%24068096/28781056 bytes (83.6%24231936/28781056 bytes (84.2%24387584/28781056 bytes (84.7%24477696/28781056 bytes (85.0%24625152/28781056 bytes (85.6%24854528/28781056 bytes (86.4%24969216/28781056 bytes (86.8%25124864/28781056 bytes (87.3%25214976/28781056 bytes (87.6%25378816/28781056 bytes (88.2%25542656/28781056 bytes (88.7%25722880/28781056 bytes (89.4%25886720/28781056 bytes (89.9%26083328/28781056 bytes (90.6%26214400/28781056 bytes (91.1%26345472/28781056 bytes (91.5%26525696/28781056 bytes (92.2%26673152/28781056 bytes (92.7%26853376/28781056 bytes (93.3%26984448/28781056 bytes (93.8%27107328/28781056 bytes (94.2%27115520/28781056 bytes (94.2 ...
#   Done
# File saved as C:\Users\masdc\AppData\Local\imageio\ffmpeg\ffmpeg.win32.exe.

# %%
from InstagramAPI import InstagramAPI
username="masdc"
InstagramAPI = InstagramAPI(username, "")
InstagramAPI.login()
# Out:
# Login success!
# True

# %%
InstagramAPI.getProfileData()
result = InstagramAPI.LastJson

# %%
print(result['status'])
print(result)
print(result['user']['email'])
# Out:
# ok
# {'user': {'has_persistent_profile_school': False, 'show_insights_terms': False, 'has_placed_orders': False, 'is_eligible_for_school': False, 'school': {}, 'can_see_organic_insights': False, 'pk': 39187, 'external_url': '', 'reel_auto_archive': 'on', 'can_boost_post': False, 'is_verified': False, 'show_conversion_edit_entry': True, 'allowed_commenter_type': 'any', 'hd_profile_pic_url_info': {'height': 200, 'url': 'https://instagram.fbog2-1.fna.fbcdn.net/vp/654641432b0f0b146f75078b828fc974/5BFD0889/t51.2885-19/12256773_194336887574110_1630003355_a.jpg', 'width': 200}, 'username': 'masdc', 'profile_pic_url': 'https://instagram.fbog2-1.fna.fbcdn.net/vp/c73b3862df041ead5d122fdae6ce5e5b/5BFA24F3/t51.2885-19/s150x150/12256773_194336887574110_1630003355_a.jpg', 'biography': 'Photography, traveling, fashion, bikes and motorcycles, software development and some musical instruments.', 'full_name': 'Millan Sanchez', 'is_private': False, 'has_anonymous_profile_picture': False, 'birthday': None, 'phone_number': '+573002064492', 'country_code': 57, 'national_number': 3002064492, 'gender': 1, 'email': 'masdc@hotmail.com', 'can_link_entities_in_bio': False}, 'status': 'ok'}
# masdc@hotmail.com

# %%
InstagramAPI.timelineFeed()
result = InstagramAPI.LastJson

# %%
print(result)
# Out:
# {'items': [{'taken_at': 1534207126, 'pk': 1845385587918468682, 'id': '1845385587918468682_193143913', 'device_timestamp': 209212466201958, 'media_type': 1, 'code': 'BmcIGo5gXZK', 'client_cache_key': 'MTg0NTM4NTU4NzkxODQ2ODY4Mg==.2', 'filter_type': 0, 'image_versions2': {'candidates': [{'width': 750, 'height': 937, 'url': 'https://instagram.fbog2-1.fna.fbcdn.net/vp/72977d80eefb8a184b9c60ec856f2f92/5C09E108/t51.2885-15/sh0.08/e35/p750x750/38992941_1126529684176239_7514203858839535616_n.jpg?ig_cache_key=MTg0NTM4NTU4NzkxODQ2ODY4Mg%3D%3D.2'}, {'width': 240, 'height': 300, 'url': 'https://instagram.fbog2-1.fna.fbcdn.net/vp/9553be2533e628192d65f0f621d984d1/5C0BEB4F/t51.2885-15/e35/p240x240/38992941_1126529684176239_7514203858839535616_n.jpg?ig_cache_key=MTg0NTM4NTU4NzkxODQ2ODY4Mg%3D%3D.2'}]}, 'original_width': 996, 'original_height': 1245, 'location': {'pk': 212941492, 'name': 'Miami, Florida', 'address': '', 'city': '', 'short_name': 'Miami', 'lng': -80.192, 'lat': 25.7752, 'external_source': 'facebook_places', 'facebook_places_id': 110148382341970}, 'lat': 25.7752, 'lng': -80.192, 'user': {'pk': 193143913, 'username': 'isaybela', 'full_name': 'Isaybela', 'is_private': False, 'profile_pic_url': 'https://instagram.fbog2-1.fna.fbcdn.net/vp/a650e948f26a467a9bafc51ad2901746/5C028592/t51.2885-19/s150x150/28427484_221785298386257_3143525295957475328_n.jpg', 'profile_pic_id': '1729181377173042256_193143913', 'friendship_status': {'following': True, 'outgoing_request': False, 'is_muting_reel': False, 'is_bestie': False}, 'is_verified': False, 'has_anonymous_profile_picture': False, 'reel_auto_archive': 'on', 'is_unpublished': False, 'is_favorite': False}, 'can_viewer_reshare': True, 'caption': {'pk': 17944169122142472, 'user_id': 193143913, 'text': 'Monday mood', 'type': 1, 'created_at': 1534207127, 'created_at_utc': 1534207127, 'content_type': 'comment', 'status': 'Active', 'bit_flags': 0, 'user': {'pk': 193143913, 'username': 'isaybela', 'full_name': 'Isaybela', 'is_private': False, 'profile_pic_url': 'https://instagram.fbog2-1.fna.fbcdn.net/vp/a650e948f26a467a9bafc51ad2901746/5C028592/t51.2885-19/s150x150/28427484_221785298386257_3143525295957475328_n.jpg', 'profile_pic_id': '1729181377173042256_193143913', 'friendship_status': {'following': True, 'outgoing_request': False, 'is_muting_reel': False, 'is_bestie': False}, 'is_verified': False, 'has_anonymous_profile_picture': False, 'reel_auto_archive': 'on', 'is_unpublished': False, 'is_favorite': False}, 'did_report_as_spam': False, 'media_id': 1845385587918468682}, 'caption_is_edited': False, 'like_count': 1570, 'has_liked': False, 'top_likers': ['alexhoyos', 'anabelizam'], 'comment_likes_enabled': True, 'comment_threading_enabled': False, 'has_more_comments': True, 'max_num_visible_preview_comments': 2, 'preview_comments': [], 'can_view_more_preview_comments': False, 'comment_count': 6, 'photo_of_you': False, 'usertags': {'in': [{'user': {'pk': 193143913, 'username': 'isaybela', 'full_name': 'Isaybela', 'is_private': False, 'is_verified': False, 'profile_pic_url': 'https://instagram.fbog2-1.fna.fbcdn.net/vp/a650e948f26a467a9bafc51ad2901746/5C028592/t51.2885-19/s150x150/28427484_221785298386257_3143525295957475328_n.jpg', 'profile_pic_id': '1729181377173042256_193143913'}, 'position': [0.6351929, 0.72179633], 'start_time_in_video_in_sec': None, 'duration_in_video_in_sec': None}]}, 'can_viewer_save': True, 'organic_tracking_token': '', 'preview': '...'}, {'taken_at': 1534203480, 'pk': 1845354999816020019, 'id': '1845354999816020019_263570282', 'device_timestamp': 1534203453744687, 'media_type': 1, 'code': 'BmcBJhghmAz', 'client_cache_key': 'MTg0NTM1NDk5OTgxNj ...

# %%
import time
myposts=[]
has_more_posts = True
max_id=""

while has_more_posts:
    InstagramAPI.getSelfUserFeed(maxid=max_id)
    if InstagramAPI.LastJson['more_available'] is not True:
        has_more_posts = False #stop condition
        print("stopped")
    
    max_id = InstagramAPI.LastJson.get('next_max_id','')
    myposts.extend(InstagramAPI.LastJson['items']) #merge lists
    time.sleep(2) # Slows the script down to avoid flooding the servers 
    
print(len(myposts))
# Out:
# stopped
# 258

# %%
import pickle
filename=username+"_posts"
pickle.dump(myposts,open(filename,"wb"))

# %%
import pickle
filename="masdc_posts"
myposts=pickle.load(file=open(filename),errors='ignore')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-31-5b05c2848d96> in <module>()
#       1 import pickle
#       2 filename="masdc_posts"
# ----> 3 myposts=pickle.load(file=open(filename),errors='ignore')
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 46: character maps to <undefined>

# %%
def display_images_from_url(url_list)
    from IPython.display import Image
    from IPython.display import display
    for url in url_list
        print(url)
        img=Image(url)
        display(img)
# Out:
#   File "<ipython-input-35-a5fbeca95204>", line 1
#     def display
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# myposts_sorted = sorted(myposts, key=lambda k:
# k['like_count'],reverse=True)
# top_posts=myposts_sorted[:10]
# bottom_posts=myposts_sorted[-10:]

# %%
image_urls=get_images_from_list(top_posts)
display_images_from_url(image_urls)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-e64e900bf71e> in <module>()
# ----> 1 image_urls=get_images_from_list(top_posts)
#       2 display_images_from_url(image_urls)
#
# NameError: name 'get_images_from_list' is not defined
